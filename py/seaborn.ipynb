# %% [raw]
#     Seaborn Visualisation for panda dataframes #introduction

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.rcParams['figure.figsize'] = 8,4
# %matplotlib inline

# %% [raw]
# Seaborn is an upgrade over matplotlib , has more accented cool features on it to make graphs sexier and fun you can say

# %%
stats = pd.read_csv("panda_data.csv")
stats.head()
stats.columns = ["CountryName","CountryCode","BirthRate","InternetUsers","IncomeGroup"]

# %%
vis1 = sns.distplot(stats["InternetUsers"])
# Out:
# /home/shivam/.virtualenvs/comviva/lib/python3.6/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [raw]
# SNS has many different types of plot which you can check by pressing tab ones you type sns.

# %%
vis2 = sns.boxplot(data = stats, x="IncomeGroup", y = "BirthRate")

# %%
vis3 = sns.lmplot(data = stats, x = "InternetUsers", y = "BirthRate")
